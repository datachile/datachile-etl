# %%
import pandas as pd
import sys
import configparser
import os
import numpy as np
config = configparser.ConfigParser()
config.read_file(open('../../settings.ini'))

sys.path.insert(0, config.get('PATHS','libs_path'))
engine_path = config.get('DATABASE','engine_path')

import postgres #from local file postgres.py
import commons
from commons import inline_table_xml, download_file, download_zip_file, extract_zip_file #from local file commons.py
from importlib import reload

import json
from sqlalchemy import create_engine
import requests

engine = create_engine(engine_path)
db = postgres.PostgresDriver(engine)

# %% [markdown]
# # Read Pacha's HS12

# %%
hs = pd.read_csv('pacha_hs12.csv')

# %%
level5 = hs[hs.hs12.str.len()==6]
level5 = level5.rename(columns={'hs12': 'level5', 'description': 'level5_en'})
level5.loc[:, 'level3'] = level5.level5.apply(lambda h: h[:4])

# %%
level3 = hs[hs.hs12.str.len()==4]
level3 = level3.rename(columns={'hs12': 'level3', 'description': 'level3_en'})
level3 = level3.merge(level5, on='level3')
level3.loc[:, 'level2'] = level3.level3.apply(lambda h: h[:2])

# %%
level2 = hs[hs.hs12.str.len() == 2]
level2 = level2.rename(columns={'hs12': 'level2', 'description': 'level2_en'})
level2 = level2.merge(level3, on='level2')

# %% [markdown]
# # HS12 from `europa.eu`

# %%
cols = ['CNKEY', 'CN', 'PURE_HS_CODE', 'LEVEL', 'EN', 'ES']
dtype = {c: str for c in cols}
dtype['LEVEL'] = int
hseu = pd.read_csv('hs2012.csv', usecols=cols, dtype=dtype)
hseu = hseu[hseu.PURE_HS_CODE.notnull()]
hseu.loc[:, 'FIXED_HS'] = hseu.PURE_HS_CODE.apply(lambda l: l.replace('.', ''))
es_hs = hseu[['FIXED_HS', 'ES']]

# %%
level2 = level2.merge(es_hs, left_on='level2', right_on='FIXED_HS')

level2 = level2.rename(columns={'ES': 'level2_es'})
level2.loc[:, 'level2_es'] = level2.level2_es.apply(lambda h: h.split(' - ')[1].title())

level2 = level2.merge(es_hs, left_on='level3', right_on='FIXED_HS', how='left')
level2 = level2.rename(columns={'ES': 'level3_es'})

level2 = level2.merge(es_hs, left_on='level5', right_on='FIXED_HS', how='left')
level2 = level2.rename(columns={'ES': 'level5_es'})

# %% [markdown]
# ### Add section names

# %%
import roman

sections = list(hseu[hseu.LEVEL==1].iterrows())
chapters = hseu[hseu.LEVEL == 2]

for (i,s1), (j,s2) in zip(sections, sections[1:]):
    level2.loc[(level2.level2.astype(int) >= int(s1.CNKEY[0:2])) & (level2.level2.astype(int) < int(s2.CNKEY[0:2])), 'level0_es'] = s1.ES
    level2.loc[(level2.level2.astype(int) >= int(s1.CNKEY[0:2])) & (level2.level2.astype(int) < int(s2.CNKEY[0:2])), 'level0_en'] = s1.EN    
    level2.loc[(level2.level2.astype(int) >= int(s1.CNKEY[0:2])) & (level2.level2.astype(int) < int(s2.CNKEY[0:2])), 'level0'] = format(roman.fromRoman(s1.CN), '02d')

# %%
flattened_hs2012 = level2[['level0', 'level0_en', 'level0_es', 'level2', 'level2_en', 'level2_es', 'level3', 'level3_en', 'level3_es', 'level5', 'level5_en', 'level5_es']]

flattened_hs2012.loc[flattened_hs2012.level0.isnull(), 'level0_en'] = "SECTION XXI - WORKS OF ART, COLLECTORS' PIECES AND ANTIQUES"
flattened_hs2012.loc[flattened_hs2012.level0.isnull(), 'level0_es'] = "SECCIÓN XXI - OBJETOS DE ARTE O COLECCIÓN Y ANTIGÜEDADES"
flattened_hs2012.loc[flattened_hs2012.level0.isnull(), 'level0'] = 21
# Out:
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
flattened_hs2012.loc[:, 'level0_es'] = flattened_hs2012.level0_es.apply(lambda h: h.split(' - ')[1].title())
flattened_hs2012.loc[:, 'level0_en'] = flattened_hs2012.level0_en.apply(lambda h: h.split(' - ')[1].title())
# Out:
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %% [markdown]
# ### Append section id to all levels

# %%
flattened_hs2012.loc[:, 'level2'] = flattened_hs2012.apply(lambda r: str(r['level0']) + r['level2'], axis=1)
flattened_hs2012.loc[:, 'level3'] = flattened_hs2012.apply(lambda r: str(r['level0']) + r['level3'], axis=1)
flattened_hs2012.loc[:, 'level5'] = flattened_hs2012.apply(lambda r: str(r['level0']) + r['level5'], axis=1)
# Out:
# /Users/jazzido/.pyenv/versions/3.6.3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %% [markdown]
# # Update names from OEC

# %%
oec_xlations_es = pd.DataFrame(requests.get("https://atlas.media.mit.edu/attr/hs92/es/").json()['data'])
oec_xlations_en = pd.DataFrame(requests.get("https://atlas.media.mit.edu/attr/hs92/en/").json()['data'])
original_hs92 = pd.read_csv('hs92.csv')

# %%
short_names = oec_xlations_es[(oec_xlations.id.str.len() == 6)] \
   .merge(original_hs92[original_hs92.Level==4], left_on='display_id', right_on='Code') \
   [['display_id', 'id', 'name', 'Description']] \
   .rename(columns={'name': 'short_name_es', 'Description': 'original_name'}) \
   .merge(oec_xlations_en, on='display_id') \
   [['display_id', 'short_name_es', 'original_name', 'name', 'id_x']] \
   .rename(columns={'name': 'short_name_en', 'id_x': 'id'})

# %%
flattened_hs2012 = flattened_hs2012.merge(short_names, left_on='level3_en', right_on='original_name', how='left') \
    [['level0', 'level0_en', 'level0_es', 'level2', 'level2_en', 'level2_es', 'level3', 'level3_en', 'level3_es', 'short_name_en', 'short_name_es', 'level5', 'level5_en', 'level5_es']] \
    .rename(columns={'short_name_en': 'level3_short_en', 'short_name_es': 'level3_short_es'})

# %%
flattened_hs2012.loc[:, 'level3_en'] = flattened_hs2012.apply(lambda h: h['level3_short_en'] if pd.notnull(h['level3_short_en']) else h['level3_en'], axis=1)
flattened_hs2012.loc[:, 'level3_es'] = flattened_hs2012.apply(lambda h: h['level3_short_es'] if pd.notnull(h['level3_short_es']) else h['level3_es'], axis=1)

# %%
flattened_hs2012
# Out:
#      level0                                      level0_en  \
# 0        01                  Live Animals; Animal Products
# 1        01                  Live Animals; Animal Products
# 2        01                  Live Animals; Animal Products
# 3        01                  Live Animals; Animal Products
# 4        01                  Live Animals; Animal Products
# 5        01                  Live Animals; Animal Products
# 9                                                Cerdos                 Pigs
# 10                                               Cerdos                 Pigs
# 11                                               Cerdos                 Pigs
# 12                                      Ovejas y cabras      Sheep and Goats
# 13                                      Ovejas y cabras      Sheep and Goats
# 14    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 15    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 16    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 17    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 18    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 19    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 20    Gallos, gallinas, patos, gansos, pavos (gallip...                  NaN
# 21                             Los demás animales vivos                  NaN
# 22                             Los demás animales vivos                  NaN
# 23                             Los demás animales vivos                  NaN
# 24                             Los demás animales vivos                  NaN
# 25                             Los demás animales vivos                  NaN
# 26                             Los demás animales vivos                  NaN
# 27                             Los demás animales vivos                  NaN
# 28                             Los demás animales vivos                  NaN
# 29                             Los demás animales vivos                  NaN
# ...                                                 ...                  ...
# 5175                                             Plumas                 Pens
# 5176                                             Plumas                 Pens
# 5177                                             Plumas                 Pens
# 5178                                 Lápices y crayones  Pencils and Crayons
# 5179                                 Lápices y crayones  Pencils and Crayons
# 5180                                 Lápices y crayones  Pencils and Crayons
# 5181                                         Pizarrones          Chalkboards
# 5182                                     Sellos de Goma        Rubber Stamps
# 5183                                    Cintas de tinta          Ink Ribbons
# 5184                                    Cintas de tinta          Ink Ribbons
# 5185                                       Encendedores             Lighters
# 5186                                       Encendedores             Lighters
# 5187                                       Encendedores             Lighters
# 5188                                       Encendedores             Lighters
# 5189                                                NaN                  NaN
# 5190                                             Peines                Combs
# 5191                                             Peines                Combs
# 5192                                             Peines                Combs
# 5193                          Pulverizadores de tocador         Scent Sprays
# 5194                          Pulverizadores de tocador         Scent Sprays
# 5195                                              Termo         Vacuum Flask
# 5196                                          Maniquíes           Mannequins
# 5197                                                NaN                  NaN
# 5198                                           Pinturas            Paintings
# 5199                                           Pinturas            Paintings
# 5200                                            Imprime               Prints
# 5201                                         Esculturas           Sculptures
# 5202                                                NaN                  NaN
# 5203                             Artículos de colección    Collector's Items
# 5204                                       Antigüedades             Antiques
#
#                 level3_short_es    level5  \
# 0                      Caballos  01010121
# 1                      Caballos  01010129
# 2                      Caballos  01010130
# 3                      Caballos  01010190
# 4                        Bovino  01010221
# 5                        Bovino  01010229
# 6                        Bovino  01010231
# 7                        Bovino  01010239
# 8                        Bovino  01010290
# 9                        Cerdos  01010310
# 10                       Cerdos  01010391
# 11                       Cerdos  01010392
# 12              Ovejas y cabras  01010410
# 13              Ovejas y cabras  01010420
# 14                          NaN  01010511
# 15                          NaN  01010512
# 16                          NaN  01010513
# 17                          NaN  01010514
# 18                          NaN  01010515
# 19                          NaN  01010594
# 20                          NaN  01010599
# 21                          NaN  01010611
# 22                          NaN  01010612
# 23                          NaN  01010613
# 24                          NaN  01010614
# 25                          NaN  01010619
# 26                          NaN  01010620
# 27                          NaN  01010631
# 5189  Smoking pipes (including pipe bowls) and cigar...
# 5190  Combs, hair slides and the like; of hard rubbe...
# 5191  Combs, hair slides and the like; of other than...
# 5192  Hairpins, curling pins, curling grips, hair cu...
# 5193  Scent sprays and similar toilet sprays, and mo...
# 5194  Powder puffs and pads; for the application of ...
# 5195  Vacuum flasks and other vacuum vessels, comple...
# 5196  Tailors' dummies and other lay figures; automa...
# 5197  Sanitary towels (pads) and tampons, napkins an...
# 5198  Paintings, drawings and pastels; executed enti...
# 5199   Artwork; collages and similar decorative plaques
# 5200       Engravings, prints and lithographs; original
# 5201  Sculptures and statuary; original, in any mate...
# 5202  Stamps, postage or revenue; stamp-postmarks, f...
# 5203  Collections and collectors' pieces; of zoologi...
# 5204    Antiques; of an age exceeding one hundred years
#
#                                               level5_es  \
# 0                            Reproductores de raza pura
# 1                                             Los demás
# 2                                                 Asnos
# 3                                             Los demás
# 4                            Reproductores de raza pura
# 5                                             Los demás
# 6                            Reproductores de raza pura
# 7                                             Los demás
# 8                                             Los demás
# 9                            Reproductores de raza pura
# 10                             De peso inferior a 50 kg
# 11                     De peso superior o igual a 50 kg
# 12                                  De la especie ovina
# 13                                De la especie caprina
# 14                                    Gallos y gallinas
# 15                                   Pavos (gallipavos)
# 16                                                Patos
# 17                                               Gansos
# 18                                             Pintadas
# 19                                    Gallos y gallinas
# 20                                            Los demás
# 21                                             Primates
# 22    Ballenas, delfines y marsopas (mamíferos del o...
# 23               Camellos y demás camélidos (Camelidae)
# 24                                    Conejos y liebres
# 25                                            Los demás
# 26    Reptiles (incluidas las serpientes y las tortu...
# 27                                       Aves de rapiña
# 28    Psitaciformes (incluidos los loros, guacamayos...
# 29         Avestruces; emúes (Dromaius novaehollandiae)
# ...                                                 ...
# 5175  Cartuchos de repuesto con su punta para bolígrafo
# 5176                  Plumillas y puntos para plumillas
# 5177                                          Los demás
# 5178                                            Lápices
# 5179                    Minas para lápices o portaminas
# 5180                                          Los demás
# 5181  Pizarras y tableros para escribir o dibujar, i...
# 5182  Fechadores, sellos, numeradores, timbradores y...
# 5183                                             Cintas
# 5184                                           Tampones
# 5185    Encendedores de gas no recargables, de bolsillo
# 5186       Encendedores de gas recargables, de bolsillo
# 5187                  Los demás encendedores y mecheros
# 5188                                             Partes
# 5189  Pipas, incluidas las cazoletas, boquillas para...
# 5190                    De caucho endurecido o plástico
# 5191                                          Los demás
# 5192                                          Los demás
# 5193  Pulverizadores de tocador, sus monturas y cabe...
# 5194  Borlas y similares para aplicación de polvos, ...
# 5195  Termos y demás recipientes isotérmicos, montad...
# 5196  Maniquíes y artículos similares; autómatas y e...
# 5197  Compresas y tampones higiénicos, pañales para ...
# 5198                                 Pinturas y dibujos
# 5199                                          Los demás
# 5200        Grabados, estampas y litografías originales
# 5201  Obras originales de estatuaria o escultura, de...
# 5202  Sellos (estampillas) de correo, timbres fiscal...
# 5203  Colecciones y especímenes para colecciones de ...
# 5204                   Antigüedades de más de cien años
#
#                                                    culo
# 0                                                Horses
# 1                                                Horses
# 2                                                Horses
# 3                                                Horses
# 4                                                Bovine
# 5                                                Bovine
# 6                                                Bovine
# 7                                                Bovine
# 8                                                Bovine
# 9                                                  Pigs
# 10                                                 Pigs
# 11                                                 Pigs
# 12                                      Sheep and Goats
# 13                                      Sheep and Goats
# 14    Poultry; live, fowls of the species Gallus dom...
# 15    Poultry; live, fowls of the species Gallus dom...
# 16    Poultry; live, fowls of the species Gallus dom...
# 17    Poultry; live, fowls of the species Gallus dom...
# 18    Poultry; live, fowls of the species Gallus dom...
# 19    Poultry; live, fowls of the species Gallus dom...
# 20    Poultry; live, fowls of the species Gallus dom...
# 21                  Animals; live, n.e.c. in chapter 01
# 22                  Animals; live, n.e.c. in chapter 01
# 23                  Animals; live, n.e.c. in chapter 01
# 24                  Animals; live, n.e.c. in chapter 01
# 25                  Animals; live, n.e.c. in chapter 01
# 26                  Animals; live, n.e.c. in chapter 01
# 27                  Animals; live, n.e.c. in chapter 01
# 28                  Animals; live, n.e.c. in chapter 01
# 29                  Animals; live, n.e.c. in chapter 01
# ...                                                 ...
# 5175                                               Pens
# 5176                                               Pens
# 5177                                               Pens
# 5178                                Pencils and Crayons
# 5179                                Pencils and Crayons
# 5180                                Pencils and Crayons
# 5181                                        Chalkboards
# 5182                                      Rubber Stamps
# 5183                                        Ink Ribbons
# 5184                                        Ink Ribbons
# 5185                                           Lighters
# 5186                                           Lighters
# 5187                                           Lighters
# 5188                                           Lighters
# 5189  Smoking pipes (including pipe bowls) and cigar...
# 5190                                              Combs
# 5191                                              Combs
# 5192                                              Combs
# 5193                                       Scent Sprays
# 5194                                       Scent Sprays
# 5195                                       Vacuum Flask
# 5196                                         Mannequins
# 5197  Sanitary towels (pads) and tampons, napkins an...
# 5198                                          Paintings
# 5199                                          Paintings
# 5200                                             Prints
# 5201                                         Sculptures
# 5202  Stamps, postage or revenue; stamp-postmarks, f...
# 5203                                  Collector's Items
# 5204                                           Antiques
#
# [5205 rows x 15 columns]

# %% [markdown]
# # Save to DB

# %%
db.to_sql(flattened_hs2012[['level0', 'level0_en', 'level0_es', 'level2', 'level2_en', 'level2_es', 'level3', 'level3_en', 'level3_es', 'level5', 'level5_en', 'level5_es']],
          'economy', 
          'dim_hs2012')

engine.execute("""
CREATE INDEX level3_idx 
ON economy.dim_hs2012 (level3)
""")

engine.execute("""
CREATE INDEX level5_idx 
ON economy.dim_hs2012 (level5)
""")
# Out:
# DROP TABLE IF EXISTS economy.dim_hs2012;
# CREATE TABLE "economy"."dim_hs2012" (
# "level0" TEXT,
#   "level0_en" TEXT,
#   "level0_es" TEXT,
#   "level2" TEXT,
#   "level2_en" TEXT,
#   "level2_es" TEXT,
#   "level3" TEXT,
#   "level3_en" TEXT,
#   "level3_es" TEXT,
#   "level5" TEXT,
#   "level5_en" TEXT,
#   "level5_es" TEXT
# )
# COPY "economy"."dim_hs2012" ("level0","level0_en","level0_es","level2","level2_en","level2_es","level3","level3_en","level3_es","level5","level5_en","level5_es") FROM STDIN WITH CSV HEADER DELIMITER ',';
