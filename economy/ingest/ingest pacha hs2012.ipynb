# %%
import pandas as pd
import sys
import configparser
import os
import numpy as np
config = configparser.ConfigParser()
config.read_file(open('../../settings.ini'))

sys.path.insert(0, config.get('PATHS','libs_path'))
engine_path = config.get('DATABASE','engine_path')

import postgres #from local file postgres.py
import commons
from commons import inline_table_xml, download_file, download_zip_file, extract_zip_file #from local file commons.py
from importlib import reload

import json
from sqlalchemy import create_engine
import requests

engine = create_engine(engine_path)
db = postgres.PostgresDriver(engine)

# %% [markdown]
# # Read Pacha's HS12

# %%
hs = pd.read_csv('pacha_hs12.csv')

# %%
level5 = hs[hs.hs12.str.len()==6]
level5 = level5.rename(columns={'hs12': 'level5', 'description': 'level5_en'})
level5.loc[:, 'level3'] = level5.level5.apply(lambda h: h[:4])

# %%
level3 = hs[hs.hs12.str.len()==4]
level3 = level3.rename(columns={'hs12': 'level3', 'description': 'level3_en'})
level3 = level3.merge(level5, on='level3')
level3.loc[:, 'level2'] = level3.level3.apply(lambda h: h[:2])

# %%
level2 = hs[hs.hs12.str.len() == 2]
level2 = level2.rename(columns={'hs12': 'level2', 'description': 'level2_en'})
level2 = level2.merge(level3, on='level2')

# %% [markdown]
# # HS12 from `europa.eu`

# %%
cols = ['CNKEY', 'CN', 'PURE_HS_CODE', 'LEVEL', 'EN', 'ES']
dtype = {c: str for c in cols}
dtype['LEVEL'] = int
hseu = pd.read_csv('hs2012.csv', usecols=cols, dtype=dtype)
hseu = hseu[hseu.PURE_HS_CODE.notnull()]
hseu.loc[:, 'FIXED_HS'] = hseu.PURE_HS_CODE.apply(lambda l: l.replace('.', ''))
es_hs = hseu[['FIXED_HS', 'ES']]

# %%
level2 = level2.merge(es_hs, left_on='level2', right_on='FIXED_HS')

# %%
level2 = level2.rename(columns={'ES': 'level2_es'})
level2.loc[:, 'level2_es'] = level2.level2_es.apply(lambda h: h.split(' - ')[1].title())

# %%
level2 = level2.merge(es_hs, left_on='level3', right_on='FIXED_HS', how='left')
level2 = level2.rename(columns={'ES': 'level3_es'})

# %%
level2 = level2.merge(es_hs, left_on='level5', right_on='FIXED_HS', how='left')
level2 = level2.rename(columns={'ES': 'level5_es'})

# %% [markdown]
# # Update names from OEC

# %%
oec_xlations = pd.DataFrame(requests.get("https://atlas.media.mit.edu/attr/hs92/es/").json()['data'])

# %%
oec_6 = oec_xlations[(oec_xlations.id.str.len() == 6)]

# %%
#oec_6['level3'] = oec_6.id.apply(lambda h: h[2:])
oec_6.loc
# Out:
#         color display_id                            icon      id  \
# 1     #FFE999       0101  /static/img/icons/hs/hs_01.png  010101
# 2     #FFE999       0102  /static/img/icons/hs/hs_01.png  010102
# 3     #FFE999       0103  /static/img/icons/hs/hs_01.png  010103
# 4     #FFE999       0104  /static/img/icons/hs/hs_01.png  010104
# 5     #FFE999       0105  /static/img/icons/hs/hs_01.png  010105
# 6     #FFE999       0106  /static/img/icons/hs/hs_01.png  010106
# 7     #FFE999       0201  /static/img/icons/hs/hs_01.png  010201
# 8     #FFE999       0202  /static/img/icons/hs/hs_01.png  010202
# 9     #FFE999       0203  /static/img/icons/hs/hs_01.png  010203
# 10    #FFE999       0204  /static/img/icons/hs/hs_01.png  010204
# 11    #FFE999       0205  /static/img/icons/hs/hs_01.png  010205
# 12    #FFE999       0206  /static/img/icons/hs/hs_01.png  010206
# 13    #FFE999       0207  /static/img/icons/hs/hs_01.png  010207
# 14    #FFE999       0208  /static/img/icons/hs/hs_01.png  010208
# 15    #FFE999       0209  /static/img/icons/hs/hs_01.png  010209
# 16    #FFE999       0210  /static/img/icons/hs/hs_01.png  010210
# 17    #FFE999       0301  /static/img/icons/hs/hs_01.png  010301
# 18    #FFE999       0302  /static/img/icons/hs/hs_01.png  010302
# 19    #FFE999       0303  /static/img/icons/hs/hs_01.png  010303
# 20    #FFE999       0304  /static/img/icons/hs/hs_01.png  010304
# 21    #FFE999       0305  /static/img/icons/hs/hs_01.png  010305
# 22    #FFE999       0306  /static/img/icons/hs/hs_01.png  010306
# 23    #FFE999       0307  /static/img/icons/hs/hs_01.png  010307
# 24    #FFE999       0401  /static/img/icons/hs/hs_01.png  010401
# 25    #FFE999       0402  /static/img/icons/hs/hs_01.png  010402
# 26    #FFE999       0403  /static/img/icons/hs/hs_01.png  010403
# 27    #FFE999       0404  /static/img/icons/hs/hs_01.png  010404
# 28    #FFE999       0405  /static/img/icons/hs/hs_01.png  010405
# 29    #FFE999       0406  /static/img/icons/hs/hs_01.png  010406
# 30    #FFE999       0407  /static/img/icons/hs/hs_01.png  010407
# ...       ...        ...                             ...     ...
# 1231  #7F7F7F       9503  /static/img/icons/hs/hs_20.png  209503
# 1232  #7F7F7F       9504  /static/img/icons/hs/hs_20.png  209504
# 1233  #7F7F7F       9505  /static/img/icons/hs/hs_20.png  209505
# 1234  #7F7F7F       9506  /static/img/icons/hs/hs_20.png  209506
# 1235  #7F7F7F       9507  /static/img/icons/hs/hs_20.png  209507
# 1236  #7F7F7F       9508  /static/img/icons/hs/hs_20.png  209508
# 1237  #7F7F7F       9601  /static/img/icons/hs/hs_20.png  209601
# 1238  #7F7F7F       9602  /static/img/icons/hs/hs_20.png  209602
# 1239  #7F7F7F       9603  /static/img/icons/hs/hs_20.png  209603
# 1240  #7F7F7F       9604  /static/img/icons/hs/hs_20.png  209604
# 1241  #7F7F7F       9605  /static/img/icons/hs/hs_20.png  209605
# 1242  #7F7F7F       9606  /static/img/icons/hs/hs_20.png  209606
# 1243  #7F7F7F       9607  /static/img/icons/hs/hs_20.png  209607
# 1244  #7F7F7F       9608  /static/img/icons/hs/hs_20.png  209608
# 1245  #7F7F7F       9609  /static/img/icons/hs/hs_20.png  209609
# 1246  #7F7F7F       9610  /static/img/icons/hs/hs_20.png  209610
# 1247  #7F7F7F       9611  /static/img/icons/hs/hs_20.png  209611
# 1248  #7F7F7F       9612  /static/img/icons/hs/hs_20.png  209612
# 1249  #7F7F7F       9613  /static/img/icons/hs/hs_20.png  209613
# 1250  #7F7F7F       9614  /static/img/icons/hs/hs_20.png  209614
# 1251  #7F7F7F       9615  /static/img/icons/hs/hs_20.png  209615
# 1252  #7F7F7F       9616  /static/img/icons/hs/hs_20.png  209616
# 1253  #7F7F7F       9617  /static/img/icons/hs/hs_20.png  209617
# 1254  #7F7F7F       9618  /static/img/icons/hs/hs_20.png  209618
# 1256  #93789E       9701  /static/img/icons/hs/hs_21.png  219701
# 1257  #93789E       9702  /static/img/icons/hs/hs_21.png  219702
# 1258  #93789E       9703  /static/img/icons/hs/hs_21.png  219703
# 1259  #93789E       9704  /static/img/icons/hs/hs_21.png  219704
# 1260  #93789E       9705  /static/img/icons/hs/hs_21.png  219705
# 1261  #93789E       9706  /static/img/icons/hs/hs_21.png  219706
#
#                                   image                    image_author  \
# 1     /static/img/headers/hs/010101.jpg             James Marvin Phelps
# 2     /static/img/headers/hs/010102.jpg  U.S. Department of Agriculture
# 3         /static/img/headers/hs/01.jpg                             NaN
# 4         /static/img/headers/hs/01.jpg                             NaN
# 5         /static/img/headers/hs/01.jpg                             NaN
# 6         /static/img/headers/hs/01.jpg                             NaN
# 7     /static/img/headers/hs/010201.jpg  U.S. Department of Agriculture
# 8     /static/img/headers/hs/010202.jpg                            Mike
# 9     /static/img/headers/hs/010203.jpg                            Mike
# 10        /static/img/headers/hs/01.jpg                             NaN
# 11        /static/img/headers/hs/01.jpg                             NaN
# 12        /static/img/headers/hs/01.jpg                             NaN
# 13    /static/img/headers/hs/010207.jpg                           to.wi
# 14        /static/img/headers/hs/01.jpg                             NaN
# 15        /static/img/headers/hs/01.jpg                             NaN
# 16        /static/img/headers/hs/01.jpg                             NaN
# 17        /static/img/headers/hs/01.jpg                             NaN
# 18    /static/img/headers/hs/010302.jpg                  Michele Ursino
# 19    /static/img/headers/hs/010303.jpg                 Derek K. Miller
# 20    /static/img/headers/hs/010304.jpg           Wheeler Cowperthwaite
# 21        /static/img/headers/hs/01.jpg                             NaN
# 22    /static/img/headers/hs/010306.jpg                   William Warby
# 23        /static/img/headers/hs/01.jpg                             NaN
# 24        /static/img/headers/hs/01.jpg                             NaN
# 25    /static/img/headers/hs/010402.jpg                      SimonQ錫濛譙
# 26        /static/img/headers/hs/01.jpg                             NaN
# 27        /static/img/headers/hs/01.jpg                             NaN
# 28    /static/img/headers/hs/010405.jpg                           Taryn
# 29    /static/img/headers/hs/010406.jpg                        Tavallai
# 30        /static/img/headers/hs/01.jpg                             NaN
# ...                                 ...                             ...
# 1231  /static/img/headers/hs/209503.jpg                Quinn Dombrowski
# 1232  /static/img/headers/hs/209504.jpg                    Images Money
# 1233      /static/img/headers/hs/20.jpg                             NaN
# 1234  /static/img/headers/hs/209506.jpg                   Alosh Bennett
# 1235      /static/img/headers/hs/20.jpg                             NaN
# 1236      /static/img/headers/hs/20.jpg                             NaN
# 1237      /static/img/headers/hs/20.jpg                             NaN
# 1238      /static/img/headers/hs/20.jpg                             NaN
# 1239      /static/img/headers/hs/20.jpg                             NaN
# 1240      /static/img/headers/hs/20.jpg                             NaN
# 1241      /static/img/headers/hs/20.jpg                             NaN
# 1242      /static/img/headers/hs/20.jpg                             NaN
# 1243      /static/img/headers/hs/20.jpg                             NaN
# 1244      /static/img/headers/hs/20.jpg                             NaN
# 1245      /static/img/headers/hs/20.jpg                             NaN
# 1246      /static/img/headers/hs/20.jpg                             NaN
# 1247      /static/img/headers/hs/20.jpg                             NaN
# 1248      /static/img/headers/hs/20.jpg                             NaN
# 1249      /static/img/headers/hs/20.jpg                             NaN
# 1250      /static/img/headers/hs/20.jpg                             NaN
# 1251      /static/img/headers/hs/20.jpg                             NaN
# 1252      /static/img/headers/hs/20.jpg                             NaN
# 1253      /static/img/headers/hs/20.jpg                             NaN
# 1254      /static/img/headers/hs/20.jpg                             NaN
# 1256                               None                             NaN
# 1257                               None                             NaN
# 1258                               None                             NaN
# 1259                               None                             NaN
# 1260                               None                             NaN
# 1261                               None                             NaN
#
#                     image_link  \
# 1     https://flic.kr/p/gMG1YC
# 2     https://flic.kr/p/o63k4J
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7     https://flic.kr/p/kUwC6M
# 8     https://flic.kr/p/5YxzLS
# 9     https://flic.kr/p/nTxu3s
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13    https://flic.kr/p/emMKXR
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18    https://flic.kr/p/goCtXJ
# 19    https://flic.kr/p/5ssw6f
# 20    https://flic.kr/p/eMgxqi
# 21                         NaN
# 22    https://flic.kr/p/8pohMk
# 23                         NaN
# 24                         NaN
# 25    https://flic.kr/p/djcxwW
# 26                         NaN
# 27                         NaN
# 28    https://flic.kr/p/bc5UpX
# 29    https://flic.kr/p/9JyFXz
# 30                         NaN
# ...                        ...
# 1231  https://flic.kr/p/c8ENP9
# 1232  https://flic.kr/p/9VCMJf
# 1233                       NaN
# 1234  https://flic.kr/p/2z1KWQ
# 1235                       NaN
# 1236                       NaN
# 1237                       NaN
# 1238                       NaN
# 1239                       NaN
# 1240                       NaN
# 1241                       NaN
# 1242                       NaN
# 1243                       NaN
# 1244                       NaN
# 1245                       NaN
# 1246                       NaN
# 1247                       NaN
# 1248                       NaN
# 1249                       NaN
# 1250                       NaN
# 1251                       NaN
# 1252                       NaN
# 1253                       NaN
# 1254                       NaN
# 1256                       NaN
# 1257                       NaN
# 1258                       NaN
# 1259                       NaN
# 1260                       NaN
# 1261                       NaN
#
#                                                keywords  \
# 1                     equino, cebra, culo, burro, mulas
# 2       ganado, búfalo, bisonte, vaca, toro, buey, toro
# 3                                                 cerdo
# 4     espolón, oveja, cordero, carnero castrado, ref...
# 5                     pollo, gallina, pavo, pato, ganso
# 6     animales del parque zoológico, animales domést...
# 7                      carne de res, filete, carne roja
# 8                      carne de res, filete, carne roja
# 9                         jamón, carne de cerdo, tocino
# 10                            cordero, carne de cordero
# 11                           equino, cebra, culo, burro
# 12    vaca, carne de vaca, caballo, los intestinos, ...
# 13                                                pollo
# 14                  carne de res, pollo, carne de cerdo
# 15                                     manteca de cerdo
# 16                                           intestinos
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                   salmón, el bacalao
# 21                                               salado
# 22    cangrejo, langosta, camarón, caracol, mejillon...
# 23    cangrejo, langosta, camarón, caracol, mejillon...
# 24                             productos lácteos, crema
# 25    productos lácteos, suero de leche, seco, nata,...
# 26                             productos lácteos, crema
# 27    productos lácteos, suero de leche, seco, nata,...
# 28                                      lácteos, grasas
# 29                               lácteos, leche cuajada
# 30                                                 None
# ...                                                 ...
# 1231  trenes eléctricos, juegos de construcción, ins...
# 1232  juegos de salón, parques de atracciones, billa...
# 1233  los niños, muñecas, mesa, cubierta, carnaval, ...
# 1234  golf, tenis, pelotas, esquís, tablas de snowbo...
# 1235  cañas de pescar, anzuelos, carretes de pesca, ...
# 1236  Tiovivos, columpios, casetas de tiro, circos, ...
# 1237  sculping, talla, hueso, concha de tortuga, cue...
# 1238  cera moldeada, estearina, goma natural, pastas...
# 1239  cestería, escobas, rodillos para pintar, cepil...
# 1240                                    cribas, de mano
# 1241  hangbags, retrete-estuches, maletines, Bandoleras
# 1242             botones de presión, botones de presión
# 1243                              cierres de cremallera
# 1244  de punta redonda, punta de fieltro, tinta indi...
# 1245                                     plomo, grafito
# 1246          pizarras, tableros, superficies de dibujo
# 1247  impresión de la mano, buscar pareja, dispositi...
# 1248                    tampones de tinta, cartuchos de
# 1249  encendedores de bolsillo, encendedores de mesa...
# 1250  cazoletas, boquillas para cigarros, boquillas ...
# 1251  pasadores para el cabello, horquillas para ond...
# 1252  Pulverizadores de tocador, almohadillas de hoj...
# 1253                                               None
# 1254                    maniquíes, maniquíes, autómatas
# 1256  dibujos, pasteles, collages, cuadros de pequeñ...
# 1257                   grabados originales, litografías
# 1258                                         estatuaria
# 1259                         franqueo, enteros postales
# 1260  monedas, zoología, botánica, mineralogía o ana...
# 1261                                               None
#
#                                    name  \
# 1                              Caballos
# 2                                Bovino
# 3                                Cerdos
# 4                       Ovejas y cabras
# 5                        Aves de corral
# 6                        Otros animales
# 7                          Carne Bovina
# 8            Congelados Carne de Bovino
# 9                        Carne de cerdo
# 10                      Ovino y caprino
# 11                     Carne de caballo
# 12                 Despojos comestibles
# 13                        Carne de Aves
# 14                           Otra Carne
# 15                      Grasa de animal
# 16                 La carne en conserva
# 17                             Pez vivo
# 18             Pescado Fresco no filete
# 19       No filete de pescado congelado
# 20                   Filetes de Pescado
# 21                    Pescado Procesado
# 22                           Crustáceos
# 23                             Moluscos
# 24                                Leche
# 25                    Leche concentrada
# 26    Los productos lácteos fermentados
# 27                                Suero
# 28                          Mantequilla
# 29                                Queso
# 30                               Huevos
# ...                                 ...
# 1231      Modelos y animales de peluche
# 1232           Vídeo y Juegos de Cartas
# 1233           Decoraciones del partido
# 1234               Equipo para Deportes
# 1235               Caza y Pesca Equipos
# 1236               Atracciones de feria
# 1237           Marfil trabajado y hueso
# 1238       Vegetales y minerales Tallas
# 1239                            Escobas
# 1240                   Tamizadoras Mano
# 1241                      Kits de viaje
# 1242                            Botones
# 1243                        Cremalleras
# 1244                             Plumas
# 1245                 Lápices y crayones
# 1246                         Pizarrones
# 1247                     Sellos de Goma
# 1248                    Cintas de tinta
# 1249                       Encendedores
# 1250                              Pipas
# 1251                             Peines
# 1252          Pulverizadores de tocador
# 1253                              Termo
# 1254                          Maniquíes
# 1256                           Pinturas
# 1257                            Imprime
# 1258                         Esculturas
# 1259                           Fiscales
# 1260             Artículos de colección
# 1261                       Antigüedades
#
#                                                 palette        weight
# 1     ["#e7f9fa","#533127","#907b65","#713928","#b66...  2.689205e+09
# 2     ["#fbfbfb","#402a1a","#976034","#2c2420","#be6...  8.346649e+09
# 3                                                   NaN  3.694108e+09
# 4                                                   NaN  2.141696e+09
# 5                                                   NaN  2.889115e+09
# 6                                                   NaN  1.306225e+09
# 7     ["#b4605a","#e6dfd4","#120c09","#f7e9d0","#020...  2.087768e+10
# 8     ["#fcfdfc","#523a38","#8b7b77","#2c1516","#a89...  2.093388e+10
# 9     ["#0e0d0d","#ecd7ca","#c89e81","#fcf7f4","#eca...  2.505188e+10
# 10                                                  NaN  6.342547e+09
# 11                                                  NaN  3.922273e+08
# 12                                                  NaN  7.135637e+09
# 13    ["#f8fdf5","#435f11","#0c0e02","#979527","#1e1...  2.419582e+10
# 14                                                  NaN  8.518525e+08
# 15                                                  NaN  4.665013e+08
# 16                                                  NaN  4.331067e+09
# 17                                                  NaN  1.931073e+09
# 18                                ["#aaa092","#29211e"]  1.453684e+10
# 19                      ["#d4af74","#040300","#55461c"]  2.073803e+10
# 20    ["#2e2727","#a5a09e","#ccd1da","#7496b9","#9bc...  2.125763e+10
# 21                                                  NaN  5.764648e+09
# 22                                ["#b7916c","#38220d"]  2.346586e+10
# 23                                                  NaN  1.072127e+10
# 24                                                  NaN  7.422152e+09
# 25            ["#fef4ef","#655755","#030106","#65141d"]  1.884508e+10
# 26                                                  NaN  4.184365e+09
# 27                                                  NaN  4.225152e+09
# 28    ["#342d32","#9d9771","#e2d198","#9da39a","#e8d...  6.741010e+09
# 29                      ["#a17017","#120201","#dde5f9"]  2.693853e+10
# 30                                                  NaN  4.175755e+09
# ...                                                 ...           ...
# 1231                    ["#a18564","#1a140c","#fbfcfd"]  3.397497e+10
# 1232  ["#f3f0ed","#3e766b","#0c0f12","#599087","#dd1...  2.513516e+10
# 1233                                                NaN  5.912081e+09
# 1234  ["#000000","#aab93b","#737c24","#ada590","#706...  2.456233e+10
# 1235                                                NaN  2.804333e+09
# 1236                                                NaN  1.350080e+09
# 1237                                                NaN  1.610153e+08
# 1238                                                NaN  9.351158e+08
# 1239                                                NaN  8.104242e+09
# 1240                                                NaN  3.661158e+07
# 1241                                                NaN  2.600833e+08
# 1242                                                NaN  1.668722e+09
# 1243                                                NaN  2.561775e+09
# 1244                                                NaN  5.757896e+09
# 1245                                                NaN  1.627233e+09
# 1246                                                NaN  5.671716e+08
# 1247                                                NaN  3.035140e+08
# 1248                                                NaN  1.724254e+09
# 1249                                                NaN  1.693709e+09
# 1250                                                NaN  2.128260e+08
# 1251                                                NaN  1.398199e+09
# 1252                                                NaN  1.295221e+09
# 1253                                                NaN  1.817130e+09
# 1254                                                NaN  6.967882e+08
# 1256                                                NaN  1.550320e+10
# 1257                                                NaN  4.362248e+08
# 1258                                                NaN  3.476565e+09
# 1259                                                NaN  1.426738e+08
# 1260                                                NaN  1.049647e+09
# 1261                                                NaN  2.800748e+09
#
# [1241 rows x 11 columns]

# %%
db.to_sql(level2[['level2', 'level2_en', 'level2_es', 'level3', 'level3_en', 'level3_es', 'level5', 'level5_en', 'level5_es']], 
          'economy', 
          'dim_hs2012')

engine.execute("""
CREATE INDEX level3_idx 
ON economy.dim_hs2012 (level3)
""")

engine.execute("""
CREATE INDEX level5_idx 
ON economy.dim_hs2012 (level5)
""")
# Out:
# DROP TABLE IF EXISTS economy.dim_hs2012;
# CREATE TABLE "economy"."dim_hs2012" (
# "level2" TEXT,
#   "level2_en" TEXT,
#   "level2_es" TEXT,
#   "level3" TEXT,
#   "level3_en" TEXT,
#   "level3_es" TEXT,
#   "level5" TEXT,
#   "level5_en" TEXT,
#   "level5_es" TEXT
# )
# COPY "economy"."dim_hs2012" ("level2","level2_en","level2_es","level3","level3_en","level3_es","level5","level5_en","level5_es") FROM STDIN WITH CSV HEADER DELIMITER ',';
